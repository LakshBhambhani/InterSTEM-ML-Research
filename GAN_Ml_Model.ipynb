# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
 

import os
from PIL import Image
image_files = []
for dirname, _, filenames in os.walk('/kaggle/input/gopro-deblur/'):
    for filename in filenames:
        file = os.path.join(dirname, filename)
        image = Image.open(file)
        print(file)
        height = 220
        width = 220
        dim = (width, height)
        res = cv2.resize(np.float32(image), dim, interpolation=cv2.INTER_LINEAR)
        print(1)
        

# # Preprocessing
# res_img = []
# def processing():
#     # loading image
#     # Getting 3 images to work with 
  
#     #print('Original size',img[0].shape)
#     # --------------------------------
#     # setting dim of the resize
#     height = 220
#     width = 220
#     dim = (width, height)
#     for files in image_files:
#         print(files)
#         res = cv2.resize('/kaggle/input/gopro-deblur/gopro-deblur/sharp/images'+ filename, dim, interpolation=cv2.INTER_LINEAR)
#         print(1)
#         #res_img.append(res)
  
#     # Checking the size
#     #print("RESIZED", res_img[0].shape)
    
#     # Visualizing one of the images in the array
#     #original = res_img[1]
#    #display_one(original)
    
    
# processing()
# Out:
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000585.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000313.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000603.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000224.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000121.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000598.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000750.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000546.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000572.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002503.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002513.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000189.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000039.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000339.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000243.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001329.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000696.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000085.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002523.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000646.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002175.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000178.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002814.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000748.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001032.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000689.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000972.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000715.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000345.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002171.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002135.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002200.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001381.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000647.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000703.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000683.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002194.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000666.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000769.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002823.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001349.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000262.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000756.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000097.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000722.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000994.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000190.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002159.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000338.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000216.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000120.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002869.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000545.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002192.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000575.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002199.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001399.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000752.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001029.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001350.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000953.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000229.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000082.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000632.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000630.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002113.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000247.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002862.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001373.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000618.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000263.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002872.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001020.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000145.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002847.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002152.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000344.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002886.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002168.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002143.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000048.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000778.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001321.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000671.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001315.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000232.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000335.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002512.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002483.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000043.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000134.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000628.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000548.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000746.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002153.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000974.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001385.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000242.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000198.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000149.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000990.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000007.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002825.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000163.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002822.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000961.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000142.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000046.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000609.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000564.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002526.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002482.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000277.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000660.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001330.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002850.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002888.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000236.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000118.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001019.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000996.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000607.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000712.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001023.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001047.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000172.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000028.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000547.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000023.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001382.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002818.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002873.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002835.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001337.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002189.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000223.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000309.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002133.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000731.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000245.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001318.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000580.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000127.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002856.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000133.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000282.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002119.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002132.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002801.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000967.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001017.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002879.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000687.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000089.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000664.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000695.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000992.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000206.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000977.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002858.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001003.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000662.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001022.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001387.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002810.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002492.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000251.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000112.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000749.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000222.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000286.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002108.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000013.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000322.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000293.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002880.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000278.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002887.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002510.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002846.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000742.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002134.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000092.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000681.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002853.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000123.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001351.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000290.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002840.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000587.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000966.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000058.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000328.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000591.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000010.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000022.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002151.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001037.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001395.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001344.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002861.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001338.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001343.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000774.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000549.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000707.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002109.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000184.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000157.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001396.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000081.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002169.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002824.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001314.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000714.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000965.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002110.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002123.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000220.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000109.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000059.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002149.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000958.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000265.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000552.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000764.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001015.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001031.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000173.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002181.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000215.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000273.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000102.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000008.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000296.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002139.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000669.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000103.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000320.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002496.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001316.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000094.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000152.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000694.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000295.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000258.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000620.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000117.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000779.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001358.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000179.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001013.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002158.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002104.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002811.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000329.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002895.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000167.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000298.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000015.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000711.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000230.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000658.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001390.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000233.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000723.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001002.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001046.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002122.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000999.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000055.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000052.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002819.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000141.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000968.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001308.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000160.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000971.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000563.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000208.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000203.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000012.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000568.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000307.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001332.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000045.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000743.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001369.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002831.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000240.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000326.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000655.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002495.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000261.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000635.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000727.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000166.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001319.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000017.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000754.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002520.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002875.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000757.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000067.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001006.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000550.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000239.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001010.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002871.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000333.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000346.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001005.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002893.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001362.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002170.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002488.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/001353.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000573.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002842.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000730.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000955.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000288.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000187.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/002166.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000728.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000741.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/000629.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/sharp/images/
png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000148.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001325.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000260.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001312.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002807.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000084.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002154.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000583.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001323.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000244.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000672.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001386.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000075.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002502.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000122.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002855.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002827.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000202.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000217.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001366.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002188.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000734.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002522.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000038.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000106.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000062.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002500.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000212.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001009.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000252.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002803.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000621.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000984.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002196.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001317.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002817.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002866.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000269.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000639.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000644.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000054.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000952.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002498.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000130.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000280.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000228.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001027.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001377.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000998.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000144.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000042.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000086.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000579.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001333.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002899.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000330.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001340.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002854.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000581.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001392.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002128.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000667.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000973.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000100.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002494.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000031.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002504.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000069.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001391.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000283.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000020.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002894.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000674.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000200.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000030.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000776.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000770.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000306.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001309.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000702.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000033.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001036.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001398.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000736.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000324.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002845.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000637.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000561.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000657.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001035.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000650.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000612.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000111.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000665.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000250.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000710.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000227.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001375.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002844.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000648.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000041.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000964.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002129.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002178.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002118.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000156.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001365.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002115.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002892.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002519.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000954.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000071.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002116.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000024.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000264.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000226.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000060.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002145.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001354.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001393.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002808.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000777.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000225.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000099.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000332.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000291.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000188.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000762.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002809.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001049.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000301.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000760.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001025.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000066.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000700.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002185.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000608.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001000.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000209.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000014.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000126.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001397.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000061.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000606.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000602.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000995.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000556.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002124.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001346.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000176.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002884.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002882.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002186.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002525.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000311.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000740.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002514.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000090.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001026.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000691.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000047.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000308.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000073.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000186.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002156.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001033.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000342.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000341.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002833.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000682.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000143.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000072.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000053.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000582.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002144.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000315.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000077.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000659.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002136.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000626.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002849.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000960.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000056.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002832.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000207.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000745.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000613.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001331.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002524.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000314.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000555.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001389.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002516.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001311.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002864.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001326.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002126.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002117.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002527.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000755.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000729.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000327.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002193.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/000319.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/002147.png
# 1
# /kaggle/input/gopro-deblur/gopro_deblur/blur/images/001359.png
# 1

# %%
print(len(image_files))
# Out:
# 2058

# %%
# Preprocessing
res_img = []
def processing(data):
    # loading image
    # Getting 3 images to work with 
  
    #print('Original size',img[0].shape)
    # --------------------------------
    # setting dim of the resize
    height = 220
    width = 220
    dim = (width, height)
    for files in data:
        res = cv2.resize(files, dim, interpolation=cv2.INTER_LINEAR)
        print(1)
        res_img.append(res)
  
    # Checcking the size
    print("RESIZED", res_img[1].shape)
    
    # Visualizing one of the images in the array
    original = res_img[1]
    display_one(original)
    
    
processing(image_files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-839ebb8a24d8> in <module>
#      24
#      25
# ---> 26 processing(image_files)
#
# NameError: name 'image_files' is not defined

# %%
import tensorflow as tf
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time

from IPython import display

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-0b2971e47091> in <module>
# ----> 1 (train_images, train_labels), (_, _) = ('/kaggle/input/gopro-deblur/')
#       2 train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
#       3 train_images = (train_images - 127.5) / 127.5 # Normalize the images to [-1, 1]
#
# ValueError: too many values to unpack (expected 2)

# %%
BUFFER_SIZE = 60000
BATCH_SIZE = 256

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256) # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)

    return model

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[28, 28, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
print(len(res_img))
# Out:
# 0

# %%
discriminator = make_discriminator_model()
generated_image = res_img[0]
decision = discriminator(generated_image)
print (decision)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-619803c7e0e5> in <module>
#       1 discriminator = make_discriminator_model()
# ----> 2 generated_image = res_img[0]
#       3 decision = discriminator(generated_image)
#       4 print (decision)
#
# IndexError: list index out of range

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)
